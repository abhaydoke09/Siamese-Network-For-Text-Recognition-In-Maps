# %% [markdown]
# ## Siamese Results Without Map Background Texture

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# import system things
import tensorflow as tf
import numpy as np
import os
import pickle
from util import get_test_results

from data_generator_for_siamese import ImageDataGenerator
from datetime import datetime
from tensorflow.contrib.data import Iterator
from tensorflow.contrib.data import Dataset
from helper import get_dataset
import siamese
from matplotlib import pyplot as plt
# %matplotlib inline

# prepare data and tf.session
sess = tf.InteractiveSession()
num_classes = 999
batch_size = 32
# setup siamese network
siamese_model = siamese.siamese_network(batch_size);
train_step = tf.train.AdamOptimizer(0.001).minimize(siamese_model.loss)
saver = tf.train.Saver()

train_file = 'word_train.txt'
val_file = 'word_val.txt'
# Place data loading and preprocessing on the cpu
with tf.device('/cpu:0'):
    tr_data = ImageDataGenerator(train_file,
                                 mode='training',
                                 batch_size=batch_size,
                                 num_classes=num_classes,
                                 shuffle=True)

sess.run(tf.global_variables_initializer())
# start training

#siamese_model.load_initial_weights(sess)
num_epochs = 300
new = False
saver.restore(sess, 'trained_models/without_bg/model.ckpt')
embed = None
flag = False

for i in range(10):
    batch_x1, batch_y1, test_words = tr_data.get_test_batch(batch_size)
    word_list = batch_x1
    result_vectors = siamese_model.o1.eval({siamese_model.x1: batch_x1})
    result = get_test_results(test_words, result_vectors)
    print("Original Image")
    plt.imshow(word_list[0])
    plt.show()
    print("*"*20)
    print("Top 5 matching images")
    print("*"*20)
    for i in range(5):
        plt.imshow(word_list[result[i][2]])
        print("Distance:", result[i][1])
        plt.show()
# Out:
# Adding Data Augmentation
# Adding Data Augmentation
# INFO:tensorflow:Restoring parameters from trained_models/without_bg/model.ckpt
# INFO:tensorflow:Restoring parameters from trained_models/without_bg/model.ckpt
# **************************************************
# Original word : McLouth
# **************************************************
# [('McLouth', 0.7948674559593201, 11), ('McLouth', 1.0152063369750977, 25), ('McLouth', 1.021846055984497, 30), ('McLouth', 1.2150909900665283, 4), ('McLouth', 1.2993100881576538, 7), ('McLouth', 1.5531105995178223, 29), ('Mallard', 2.0037589073181152, 16), ('Mikkalo', 2.4436073303222656, 24), ('Duxbury', 2.5132639408111572, 17), ('WestEnd', 2.9258246421813965, 2), ('Westway', 3.0736193656921387, 31), ('Hobgood', 3.2265119552612305, 1), ('Conrath', 3.230733871459961, 15), ('LaJunta', 3.6093335151672363, 13), ('Aurelia', 3.7291176319122314, 23), ('Linneus', 3.8514034748077393, 21), ('McLouth', 3.8974032402038574, 5), ('Chauvin', 3.9416310787200928, 14), ('TheGlen', 4.034265041351318, 9), ('Allouez', 4.236362934112549, 28), ('Tyndall', 4.286996841430664, 8), ('Leander', 4.406580448150635, 22), ('Winfred', 4.713743686676025, 12), ('Chelyan', 4.722431182861328, 20), ('Crandon', 4.7472615242004395, 3), ('Royston', 4.843334674835205, 19), ('Shaniko', 4.896844863891602, 27), ('Vieques', 5.248048782348633, 26), ('Freedom', 5.267019748687744, 6), ('Elfrida', 5.6283955574035645, 10), ('Cascade', 6.046880722045898, 18)]
# Original Image
# ********************
# Top 5 matching images
# ********************
# Distance: 0.794867455959
# Distance: 1.01520633698
# Distance: 1.02184605598
# Distance: 1.21509099007
# Distance: 1.29931008816
# **************************************************
# Original word : Peyton
# **************************************************
# [('Peyton', 0.3853710889816284, 18), ('Peyton', 0.6971577405929565, 1), ('Peyton', 0.9341265559196472, 7), ('Peyton', 1.0686589479446411, 30), ('Peyton', 2.3079164028167725, 3), ('Peyton', 2.332284688949585, 24), ('Salina', 2.4982826709747314, 12), ('Peyton', 2.5609285831451416, 6), ('Eldena', 2.8324012756347656, 5), ('Concow', 3.4803078174591064, 20), ('Curlew', 3.507176637649536, 10), ('Denton', 4.069934844970703, 2), ('Hatton', 4.154777526855469, 28), ('Pataha', 4.281618595123291, 31), ('Cuervo', 4.377368927001953, 13), ('Corwin', 4.422142028808594, 26), ('Corder', 4.8064985275268555, 27), ('Millen', 5.032734394073486, 17), ('Burley', 5.082049369812012, 23), ('Tushka', 5.183981895446777, 21), ('Horine', 5.986975193023682, 15), ('Hector', 6.091992378234863, 19), ('Amiret', 6.332693099975586, 11), ('Mentor', 6.414163589477539, 14), ('Nenzel', 6.961787223815918, 8), ('Flores', 7.512557506561279, 29), ('Mullan', 8.068862915039062, 25), ('Mocane', 8.627876281738281, 4), ('Nemaha', 8.936592102050781, 16), ('Margie', 9.122879981994629, 9), ('Manvel', 9.177148818969727, 22)]
# Original Image
# ********************
# Top 5 matching images
# ********************
# Distance: 0.385371088982
# Distance: 0.697157740593
# Distance: 0.93412655592
# Distance: 1.06865894794
# Distance: 2.30791640282
# **************************************************
# Original word : PortHuron
# **************************************************
# [('PortHuron', 0.4764198362827301, 11), ('PortHuron', 0.7496622204780579, 30), ('PortHuron', 1.1733126640319824, 23), ('PortHuron', 1.2054963111877441, 31), ('PortHuron', 1.9552267789840698, 1), ('PilotKnob', 2.002286434173584, 19), ('Nondalton', 2.735905170440674, 7), ('PolkInlet', 2.8104143142700195, 14), ('PortHuron', 2.918959617614746, 5), ('Braselton', 2.964893102645874, 25), ('StateLine', 3.0245418548583984, 21), ('Tontitown', 3.062551736831665, 10), ('Catharine', 3.097468614578247, 28), ('BlueRiver', 3.1717565059661865, 29), ('Millhurst', 3.1739466190338135, 8), ('PortHuron', 3.186231851577759, 20), ('PortHuron', 3.326655864715576, 24), ('Telegraph', 3.6512339115142822, 13), ('FortSmith', 3.8324384689331055, 9), ('Topsfield', 3.9991533756256104, 3), ('Bethayres', 4.053772926330566, 15), ('Shallotte', 4.057429790496826, 22), ('LosIndios', 4.079103946685791, 16), ('TwinLakes', 4.17311954498291, 12), ('Sugartown', 4.299659252166748, 27), ('Honokahua', 4.31809139251709, 2), ('Brownwood', 4.349008560180664, 17), ('PineHaven', 4.924532890319824, 18), ('Melbourne', 5.251640796661377, 26), ('AguaDulce', 6.090303421020508, 4), ('WhalePass', 7.920875549316406, 6)]
# Original Image
# ********************
# Top 5 matching images
# ********************
# Distance: 0.476419836283
# Distance: 0.749662220478
# Distance: 1.17331266403
# Distance: 1.20549631119
# Distance: 1.95522677898
# **************************************************
# Original word : Delaplaine
# **************************************************
# [('Delaplaine', 1.390856146812439, 23), ('Delaplaine', 1.750930666923523, 1), ('Delaplaine', 1.7821074724197388, 5), ('Delaplaine', 2.0876200199127197, 8), ('Cooksville', 2.608802080154419, 29), ('Burlingame', 2.825798749923706, 12), ('Stacyville', 2.902458906173706, 11), ('Fieldsboro', 2.9370217323303223, 9), ('SpringCity', 3.0052340030670166, 4), ('PuertoReal', 3.182950019836426, 6), ('BeechBluff', 3.3383798599243164, 24), ('Battleboro', 3.7471935749053955, 19), ('Shaktoolik', 4.044826984405518, 2), ('SuttonsBay', 4.062509059906006, 13), ('NorthRiver', 4.237175941467285, 30), ('SanGabriel', 4.31119441986084, 7), ('Delaplaine', 4.411775588989258, 25), ('Delaplaine', 4.726022243499756, 27), ('Delaplaine', 4.86141300201416, 20), ('Waldenburg', 5.162817478179932, 28), ('Wessington', 5.208205223083496, 15), ('Haverstraw', 5.46624755859375, 16), ('PortMayaca', 5.504122734069824, 17), ('Plantation', 5.593690872192383, 22), ('Noblestown', 5.823329448699951, 18), ('Delaplaine', 5.846981048583984, 14), ('FortMorgan', 6.1633710861206055, 10), ('BeachHaven', 6.241702079772949, 3), ('MountJudea', 6.840738296508789, 21), ('SaintMarys', 7.358322620391846, 26), ('Dundarrach', 7.467325210571289, 31)]
# Original Image
# ********************
# Top 5 matching images
# ********************
# Distance: 1.39085614681
# Distance: 1.75093066692
# Distance: 1.78210747242
# Distance: 2.08762001991
# Distance: 2.60880208015
# **************************************************
# Original word : Day
# **************************************************
# [('Day', 1.0552647113800049, 23), ('Day', 1.5244427919387817, 29), ('Day', 1.5390814542770386, 4), ('Amo', 1.7178667783737183, 26), ('Day', 1.7694077491760254, 8), ('Igo', 1.9003939628601074, 10), ('Van', 1.937537670135498, 2), ('Jay', 1.9493876695632935, 11), ('Ila', 1.9994776248931885, 20), ('Toy', 2.01163649559021, 3), ('Day', 2.1597306728363037, 13), ('Jal', 2.253847599029541, 7), ('Leo', 2.367751121520996, 27), ('Sun', 2.468485116958618, 15), ('Fox', 2.518371105194092, 31), ('Day', 2.585191249847412, 16), ('Day', 2.958395481109619, 22), ('Lum', 3.2039668560028076, 21), ('Ono', 3.2844815254211426, 14), ('Ney', 3.77128005027771, 30), ('Ulm', 3.888634204864502, 18), ('Joy', 3.8992788791656494, 1), ('War', 3.9050731658935547, 24), ('Day', 4.008641719818115, 9), ('Hye', 4.264218807220459, 6), ('Hye', 4.600315570831299, 19), ('Abo', 4.632608890533447, 5), ('Nye', 4.772812366485596, 12), ('Day', 4.8473286628723145, 28), ('Day', 5.382719039916992, 25), ('May', 7.340792179107666, 17)]
# Original Image
# ********************
# Top 5 matching images
# ********************
# Distance: 1.05526471138
# Distance: 1.52444279194
# Distance: 1.53908145428
# Distance: 1.71786677837
# Distance: 1.76940774918
# **************************************************
# Original word : Marlborough
# **************************************************
# [('Marlborough', 1.0561274290084839, 8), ('Marlborough', 1.1464704275131226, 15), ('Marlborough', 1.2267916202545166, 27), ('Gandeeville', 1.8655109405517578, 16), ('Brandenberg', 2.069572687149048, 21), ('Marlborough', 2.114915132522583, 9), ('BrassCastle', 2.285980463027954, 10), ('Hollansburg', 2.3241262435913086, 6), ('Moreauville', 2.3539602756500244, 30), ('Parishville', 2.4944770336151123, 29), ('Marlborough', 2.630899429321289, 26), ('Marlborough', 2.703763246536255, 20), ('Connorville', 2.71797776222229, 19), ('NewFlorence', 2.721684694290161, 25), ('Leakesville', 2.807034969329834, 31), ('LakeWissota', 2.906186103820801, 7), ('Marlborough', 2.934878349304199, 24), ('Murrayville', 2.9606151580810547, 2), ('Marlborough', 3.058258295059204, 14), ('RobertaMill', 3.1269168853759766, 4), ('Marlborough', 3.4065983295440674, 22), ('LakeLucerne', 3.4763944149017334, 3), ('Morganfield', 3.4931588172912598, 13), ('Marlborough', 3.6099724769592285, 17), ('MarbleCliff', 3.643306255340576, 1), ('WestBristol', 3.925830602645874, 28), ('TremontCity', 4.0752997398376465, 18), ('Nicholville', 4.085444450378418, 5), ('McCallCreek', 4.1921844482421875, 23), ('LittleFlock', 5.137234210968018, 12), ('MillVillage', 5.830712795257568, 11)]
# Original Image
# ********************
# Top 5 matching images
# ********************
# Distance: 1.05612742901
# Distance: 1.14647042751
# Distance: 1.22679162025
# Distance: 1.86551094055
# Distance: 2.06957268715
# **************************************************
# Original word : Catskill
# **************************************************
# [('Catskill', 0.8222718238830566, 18), ('Catskill', 0.9948063492774963, 9), ('Catskill', 1.0458790063858032, 28), ('Catskill', 1.178755283355713, 29), ('Catskill', 1.2020882368087769, 22), ('Catskill', 1.202643632888794, 19), ('Catskill', 1.3038878440856934, 26), ('Catskill', 1.321718692779541, 13), ('Catskill', 1.4192053079605103, 27), ('Catskill', 1.78333580493927, 17), ('Golfview', 1.835479497909546, 7), ('Catskill', 2.1078953742980957, 5), ('Hinckley', 2.112255096435547, 20), ('Carrboro', 2.6900532245635986, 11), ('Riverton', 2.722717761993408, 25), ('Lilbourn', 2.731109142303467, 3), ('Hoolehua', 2.8543787002563477, 15), ('GaryCity', 2.865194082260132, 12), ('Trujillo', 3.0879695415496826, 23), ('Brainerd', 3.5372509956359863, 2), ('LongMott', 4.031713008880615, 4), ('Thompson', 4.06234884262085, 6), ('Oelrichs', 4.170628070831299, 8), ('Philmont', 4.196534156799316, 14), ('Covedale', 4.319382667541504, 16), ('Hathaway', 4.346538066864014, 1), ('Maypearl', 4.409235954284668, 31), ('Ducktown', 4.806072235107422, 21), ('Bergholz', 4.996682643890381, 24), ('Brockway', 6.662749767303467, 30), ('Macungie', 7.517678260803223, 10)]
# Original Image
# ********************
# Top 5 matching images
# ********************
# Distance: 0.822271823883
# Distance: 0.994806349277
# Distance: 1.04587900639
# Distance: 1.17875528336
# Distance: 1.20208823681
# **************************************************
# Original word : McWhorter
# **************************************************
# [('McWhorter', 0.886795163154602, 5), ('McWhorter', 1.409172773361206, 21), ('McWhorter', 1.6304274797439575, 22), ('McWhorter', 1.8379130363464355, 19), ('McWhorter', 1.9164866209030151, 27), ('McWhorter', 2.3864083290100098, 7), ('McWhorter', 2.7056264877319336, 16), ('McWhorter', 3.1359267234802246, 3), ('Dunstable', 4.332737922668457, 13), ('McWhorter', 5.732761859893799, 15), ('McWhorter', 5.776442050933838, 6), ('Lewisburg', 5.8062543869018555, 11), ('Hurricane', 5.875113487243652, 9), ('Ellenwood', 5.89606237411499, 24), ('Thornburg', 5.901512622833252, 26), ('Kanopolis', 6.280298709869385, 10), ('Schneider', 6.512162685394287, 1), ('Knoxville', 6.598827838897705, 4), ('Flagstaff', 6.600630283355713, 17), ('Alvordton', 6.605873107910156, 25), ('Watertown', 7.131654739379883, 12), ('Ellisburg', 7.141946792602539, 20), ('Stockport', 7.226659774780273, 31), ('Greystone', 7.243124485015869, 8), ('Callicoon', 7.32816743850708, 29), ('Dotyville', 8.250150680541992, 23), ('Keeneland', 8.266945838928223, 18), ('TroyHills', 8.354619979858398, 28), ('Amsterdam', 8.435713768005371, 30), ('EgyptLake', 9.051637649536133, 14), ('Brewerton', 9.295808792114258, 2)]
# Original Image
# ********************
# Top 5 matching images
# ********************
# Distance: 0.886795163155
# Distance: 1.40917277336
# Distance: 1.63042747974
# Distance: 1.83791303635
# Distance: 1.9164866209
# **************************************************
# Original word : Runnells
# **************************************************
# [('Runnells', 0.6679890751838684, 6), ('Runnells', 0.9547026753425598, 29), ('Runnells', 1.3174599409103394, 17), ('Accokeek', 1.6534451246261597, 3), ('Grampian', 1.701375126838684, 21), ('Rockford', 1.9071662425994873, 15), ('Rockport', 1.9224328994750977, 13), ('Runnells', 2.048372745513916, 20), ('Bokchito', 2.0594990253448486, 26), ('Runnells', 2.0780582427978516, 5), ('LaVerkin', 2.312756299972534, 1), ('Shingler', 2.459702968597412, 7), ('Arbuckle', 2.9375674724578857, 19), ('Bergholz', 3.2269771099090576, 11), ('Nazareth', 3.2534165382385254, 14), ('Standrod', 3.4531540870666504, 4), ('Chaumont', 3.495863199234009, 30), ('Leonidas', 3.651299238204956, 22), ('Rossiter', 3.7514126300811768, 24), ('Ooltewah', 3.862715482711792, 2), ('Schaller', 4.2092976570129395, 16), ('Brillion', 4.247615337371826, 18), ('Fentress', 4.579699516296387, 31), ('Syracuse', 4.901317119598389, 8), ('Westmont', 5.042788982391357, 28), ('Runnells', 6.136423110961914, 25), ('Runnells', 6.478248119354248, 27), ('Runnells', 6.51260232925415, 10), ('Runnells', 6.603025436401367, 12), ('Dunnegan', 6.854280471801758, 9), ('Chalmers', 7.405821323394775, 23)]
# Original Image
# ********************
# Top 5 matching images
# ********************
# Distance: 0.667989075184
# Distance: 0.954702675343
# Distance: 1.31745994091
# Distance: 1.65344512463
# Distance: 1.70137512684
# **************************************************
# Original word : Verbena
# **************************************************
# [('Verbena', 1.1429295539855957, 12), ('LimRock', 1.704817771911621, 2), ('Verbena', 1.9366786479949951, 17), ('Verbena', 2.0165891647338867, 25), ('ElMango', 2.102309465408325, 24), ('Verbena', 2.125797748565674, 4), ('Bartolo', 2.7501776218414307, 21), ('Ardmore', 2.7693567276000977, 7), ('Verbena', 3.0262835025787354, 11), ('Cowarts', 3.2560274600982666, 1), ('Deseret', 3.4206814765930176, 19), ('Gregory', 3.789987564086914, 3), ('Verbena', 3.897735118865967, 29), ('Waynoka', 3.9099338054656982, 14), ('Catawba', 4.048650741577148, 23), ('Leshara', 4.365241527557373, 6), ('Ligurta', 4.386853218078613, 16), ('Verbena', 4.458388805389404, 13), ('Leflore', 4.58738374710083, 20), ('Winlock', 5.130167484283447, 22), ('Hackett', 5.167628765106201, 8), ('Thiells', 5.281906604766846, 15), ('Lourdes', 5.29994010925293, 30), ('Linwood', 5.369781494140625, 18), ('Kinwood', 5.42227840423584, 31), ('Griffin', 5.986805438995361, 5), ('Skyline', 6.212353229522705, 27), ('Jamison', 6.714649200439453, 26), ('Pyramid', 7.000532150268555, 10), ('Hilland', 7.763929843902588, 9), ('Lynndyl', 8.168172836303711, 28)]
# Original Image
# ********************
# Top 5 matching images
# ********************
# Distance: 1.14292955399
# Distance: 1.70481777191
# Distance: 1.93667864799
# Distance: 2.01658916473
# Distance: 2.10230946541
